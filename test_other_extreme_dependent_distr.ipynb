# %%
from extreme_utils import *
import matplotlib.pyplot as plt
from scipy.stats import genextreme 
from tqdm import tqdm
import numpy as np

# %%
inv_gamma = 2
size_sample = 100000
order_dependency = 10

sample_student = get_dependant_frechet_max(inv_gamma, size_sample, order_dependency, distrib="student")

plt.hist(sample_student, log=True)
plt.title("Student distribution")
plt.show()
fit = genextreme.fit(sample_student)
print(fit)
# Out:
# (-0.3833030716846616, 0.19727783168084578, 0.13507121539004804)

# %%
inv_gamma = 10
size_sample = 10000
order_dependency = 10

sample_student = get_dependant_frechet_max(inv_gamma, size_sample, order_dependency, distrib="pareto")

plt.hist(sample_student, log=True)
plt.title("Student distribution")
plt.show()
fit = genextreme.fit(sample_student)
print(fit)
# Out:
# (-0.14012676310307856, 0.12616494670906553, 0.01166045149176436)
