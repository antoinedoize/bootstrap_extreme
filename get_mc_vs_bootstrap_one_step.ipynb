# %% [markdown]
# ## Bootstrap variance vs Monte-Carlo variance for one step : de_hann_98 + kulik

# %%
from main_functions import *


list_methods = [
    {"method_name": "de_hann_98",
     "method": get_bootstrap_variance_de_hann_98,
     "size_sample_bootstrap_ratio": 0.8
    },
    {"method_name": "kulik",
     "method": get_bootstrap_variance_kulik,
     "size_sample_bootstrap_ratio": 1
    }
] 

inv_gamma = 3
nb_monte_carlo_steps = 50
nb_bootstrap_steps = 50
size_sample = 10000
output_dict = get_bootstrap_vs_monte_carlo(nb_monte_carlo_steps,
                                nb_bootstrap_steps,
                                inv_gamma,
                                size_sample,
                                list_methods,
                                k_order_statistic=int(0.1*size_sample))


print("mc_hill_std",output_dict["monte_carlo_std"])
print("mc_hill",output_dict["m_c_hill_estimator_mean"])
print("de_hann_98_std",np.mean(output_dict["de_hann_98_std"]))
print("kulik_std",np.mean(output_dict["kulik_std"]))     

plt.plot(output_dict["de_hann_98_std"], label="de_hann_98")
plt.plot(output_dict["kulik_std"], label="kulik_std")
plt.plot([output_dict["monte_carlo_std"] for i in range(len(output_dict["kulik_std"]))], label="mc_std")
plt.title("Standard deviation for each monte carlo step")
plt.legend()
plt.show()
plt.plot(output_dict["k_order_statistic"], label="k_order_statistic")
plt.title("k_order_statistic for each monte carlo step")
plt.legend()
plt.show()
# Out:
# monte_carlo steps:   0%|          | 0/50 [00:00<?, ?it/s]
# mc_hill_std 0.3452769177653866
# mc_hill 0.3406397641878131
# de_hann_98_std 0.3124685569892341
# kulik_std 0.7956671785114299

# %%
from main_functions import *


list_methods = [
    {"method_name": "de_hann_98",
     "method": get_bootstrap_variance_de_hann_98,
     "size_sample_bootstrap_ratio": 0.8
    },
    {"method_name": "kulik",
     "method": get_bootstrap_variance_kulik,
     "size_sample_bootstrap_ratio": 1
    }
] 

inv_gamma = 3
nb_monte_carlo_steps = 100
nb_bootstrap_steps = 100
size_sample = 5000
output_dict = get_bootstrap_vs_monte_carlo(nb_monte_carlo_steps,
                                nb_bootstrap_steps,
                                inv_gamma,
                                size_sample,
                                list_methods,
                                k_order_statistic=int(0.1*size_sample))



print("mc_hill_std",output_dict["monte_carlo_std"])
print("mc_hill",output_dict["m_c_hill_estimator_mean"])
print("de_hann_98_std",np.mean(output_dict["de_hann_98_std"]))
print("kulik_std",np.mean(output_dict["kulik_std"]))      

plt.plot(output_dict["de_hann_98_std"], label="de_hann_98")
plt.plot(output_dict["kulik_std"], label="kulik_std")
plt.plot([output_dict["monte_carlo_std"] for i in range(len(output_dict["kulik_std"]))], label="mc_std")
plt.title("Standard deviation for each monte carlo step")
plt.legend()
plt.show()
plt.plot(output_dict["k_order_statistic"], label="k_order_statistic")
plt.title("k_order_statistic for each monte carlo step")
plt.legend()
plt.show()
# Out:
# monte_carlo steps:   0%|          | 0/100 [00:00<?, ?it/s]
# mc_hill_std 0.3086072104935262
# mc_hill 0.34258786291552956
# de_hann_98_std 0.3084100616855487
# kulik_std 0.7832223411130791

# %%
from main_functions import *


list_methods = [
    {"method_name": "de_hann_98",
     "method": get_bootstrap_variance_de_hann_98,
     "size_sample_bootstrap_ratio": 0.8
    },
    {"method_name": "kulik",
     "method": get_bootstrap_variance_kulik,
     "size_sample_bootstrap_ratio": 1
    }
] 

inv_gamma = 3
nb_monte_carlo_steps = 50
nb_bootstrap_steps = 50
size_sample = 10000
output_dict = get_bootstrap_vs_monte_carlo(nb_monte_carlo_steps,
                                nb_bootstrap_steps,
                                inv_gamma,
                                size_sample,
                                list_methods)

print("mc_hill_std",output_dict["monte_carlo_std"])
print("mc_hill",output_dict["m_c_hill_estimator_mean"])
print("de_hann_98_std",np.mean(output_dict["de_hann_98_std"]))
print("kulik_std",np.mean(output_dict["kulik_std"]))     

plt.plot(output_dict["de_hann_98_std"], label="de_hann_98")
plt.plot(output_dict["kulik_std"], label="kulik_std")
plt.plot([output_dict["monte_carlo_std"] for i in range(len(output_dict["kulik_std"]))], label="mc_std")
plt.title("Standard deviation for each monte carlo step")
plt.legend()
plt.show()
plt.plot(output_dict["k_order_statistic"], label="k_order_statistic")
plt.title("k_order_statistic for each monte carlo step")
plt.legend()
plt.show()
# Out:
# monte_carlo steps:   0%|          | 0/50 [00:00<?, ?it/s]
# mc_hill_std 6.973488265189718
# mc_hill 0.3602561404572495
# de_hann_98_std 0.32158678338659996
# kulik_std 1.2256807470386801

# %%
from main_functions import *


list_methods = [
    {"method_name": "de_hann_98",
     "method": get_bootstrap_variance_de_hann_98,
     "size_sample_bootstrap_ratio": 0.8
    },
    {"method_name": "kulik",
     "method": get_bootstrap_variance_kulik,
     "size_sample_bootstrap_ratio": 1
    }
] 

inv_gamma = 3
nb_monte_carlo_steps = 50
nb_bootstrap_steps = 50
size_sample = 5000
output_dict = get_bootstrap_vs_monte_carlo(nb_monte_carlo_steps,
                                nb_bootstrap_steps,
                                inv_gamma,
                                size_sample,
                                list_methods)

print("mc_hill_std",output_dict["monte_carlo_std"])
print("mc_hill",output_dict["m_c_hill_estimator_mean"])
print("de_hann_98_std",np.mean(output_dict["de_hann_98_std"]))
print("kulik_std",np.mean(output_dict["kulik_std"]))     

plt.plot(output_dict["de_hann_98_std"], label="de_hann_98")
plt.plot(output_dict["kulik_std"], label="kulik_std")
plt.plot([output_dict["monte_carlo_std"] for i in range(len(output_dict["kulik_std"]))], label="mc_std")
plt.title("Standard deviation for each monte carlo step")
plt.legend()
plt.show()
plt.plot(output_dict["k_order_statistic"], label="k_order_statistic")
plt.title("k_order_statistic for each monte carlo step")
plt.legend()
plt.show()
# Out:
# monte_carlo steps:   0%|          | 0/50 [00:00<?, ?it/s]
# mc_hill_std 5.17068424585167
# mc_hill 0.35924202240588676
# de_hann_98_std 0.2945004554485858
# kulik_std 1.1825669067188191
